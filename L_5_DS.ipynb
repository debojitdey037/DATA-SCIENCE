# %% [markdown]
# <a href="https://colab.research.google.com/github/debojitdey037/DATA-SCIENCE/blob/main/L_5_DS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

dct = {
    'name': ['Tom','Nick','Krish','Jack'],
    'age': [20,21,19,18],
    'roll': [1,2,3,4]
}
df = pd.DataFrame(dct,index = ['a','b','c','d'])
display(df)

df1 = pd.DataFrame(dct)
display(df1)

# %%
df = pd.read_csv("student_data.csv")
df.head(6)
df.tail()

# %%
df = pd.read_csv("student_data.csv")

df.shape

df.info() # Gives metadata of any file

# %%
df = pd.read_csv("student_data.csv")

df.describe()

#q1 = 1st quartile
#q2 = 2nd quartile = MEDIAN
#q3 = 3rd quartile

# IQR = q3 - q1

df.columns

df.index

# %%
df = pd.read_csv("student_data.csv")

# df[['study_hours','internet_usage']]

df['study_hours']     # To access the column

# df.iloc[5]      # To access the row
# df.iloc[0: 5]


df.loc[df['study_hours']==11,['study_hours','sleep_hours']].iloc[4:8]

df.loc[df['study_hours']==11][['study_hours','sleep_hours']]



# iloc and loc both access the data row wise
# iloc works on index
# loc works on label/condition

# %%
df = pd.read_csv("student_data.csv")

df.loc[df['assignments_completed']==8].iloc[1]


df.rename(columns = {'assignments_completed': 'asign_completed'},inplace = True)

df

# %%
df = pd.read_csv("student_data.csv")


df.drop('attendance', axis = 1) # Remove Rows and Column

# df.dropna() # Remove missing values

df.sort_index(axis = 1) #Sort values by column

df.sort_index()   # Sort index

df.isnull()  # Check for missing values

df.notnull() # Check for non-missing values

df.fillna() # Replace missing values

df.unique() # Find missing values for series only

df.agg() # Aggregate multiple statistics
