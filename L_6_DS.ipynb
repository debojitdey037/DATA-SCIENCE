# %% [markdown]
# <a href="https://colab.research.google.com/github/debojitdey037/DATA-SCIENCE/blob/main/L_6_DS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# LEETCODE QUESTION N0 1757

import pandas as pd

def find_products(products: pd.DataFrame) -> pd.DataFrame:
    df = products[(products['low_fats']=='Y') & (products['recyclable']=='Y')]
    return df[['product_id']]

# %%
# LEETCODE QUESTION N0 584

import pandas as pd

def find_customer_referee(customer: pd.DataFrame) -> pd.DataFrame:
    df = customer[(customer['referee_id'] != 2) | (customer['referee_id'].isna())]
    return df[['name']]

# %%
# LEETCODE QUESTION N0 595

import pandas as pd

def big_countries(world: pd.DataFrame) -> pd.DataFrame:

    df = world[(world['area'] >= 3000000 ) | (world['population'] >= 25000000)]

    return df[['name','population','area']]

# %%
import pandas as pd

df = pd.read_csv('student_data.csv')

# %%
df.groupby('placement_status')['placement_status'].agg('count')

# %%
df.groupby('placement_status')['exam_score'].agg('mean')

# %%
df.groupby('placement_status')['study_hours'].agg('mean')

# %%
df.groupby('study_hours')['exam_score'].agg('mean')

# %%
def grades(score):
  if score >= 90:
      return 'A'
  elif score >= 80:
      return 'B'
  elif score >= 70:
      return 'C'
  elif score >= 60:
      return 'D'
  else:
      return 'F'

df['grade']=df['exam_score'].apply(grades)
df

# %%
# JOINS

# 1. Inner Join
# 2. Left Join
# 3. Right Join
# 4. Outer Join
